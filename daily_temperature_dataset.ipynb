# %%
import pandas as pd 
import matplotlib.pyplot as plt 
from sklearn.preprocessing import MinMaxScaler 

path = "https://raw.githubusercontent.com/jbrownlee/Datasets/master/daily-min-temperatures.csv"

data = pd.read_csv(path, header=0, index_col=0, parse_dates=[0])

data.head()
# Out:
#             Temp
# Date
# 1981-01-01  20.7
# 1981-01-02  17.9
# 1981-01-03  18.8
# 1981-01-04  14.6
# 1981-01-05  15.8

# %%
plt.figure(figsize=(16, 8), dpi=160)
plt.plot(data)
plt.show()

# %%
#Data normalization 
values = data.values
values = values.reshape(len(values), 1)

scaler = MinMaxScaler(feature_range=(0,1))
scaler = scaler.fit(values)

normalized = scaler.transform(values)

print(normalized)
# Out:
# [[0.78707224]
#  [0.68060837]
#  [0.7148289 ]
#  ...
#  [0.51330798]
#  [0.59695817]
#  [0.49429658]]

# %%
plt.figure(figsize=(16, 8), dpi=160)
plt.plot(normalized)
plt.show()

# %%
from sklearn.preprocessing import StandardScaler 

std_scaler = StandardScaler()
model = std_scaler.fit(values)

std_norm = model.transform(values)

std_norm
# Out:
# array([[2.33888328],
#        [1.65113873],
#        [1.87219948],
#        ...,
#        [0.5703973 ],
#        [1.11076801],
#        [0.44758577]])
